# %% [markdown]
# #### Langchain Practice

# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyAZMfsPGDDoWC5LcRZLQDV4bcl9EQRkHzU"

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

print(llm.invoke("Hello, how are you?").content)
# Out:
# Hello! I'm functioning perfectly and ready to assist you.
#
# How are you doing today? And what can I help you with?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.document_loaders import TextLoader

llm = ChatGoogleGenerativeAI()
docs = TextLoader("./data.txt").load()
print(docs)
# Out:
# [Document(metadata={'source': './data.txt'}, page_content='Title: Quarterly Performance Review – Q4 2025\n\nExecutive Summary:\nIn Q4 2025, our company achieved a 12% increase in revenue compared to Q3, driven primarily by strong sales in the Asia-Pacific region. Customer satisfaction scores rose from 82% to 88%, reflecting improvements in product quality and support response times.\n\nKey Highlights:\n- Revenue: $45M (up from $40M in Q3)\n- Net Profit Margin: 18%\n- Top Market: India (accounted for 35% of total sales)\n- New Product Launch: SmartHome Hub 2.0 received positive reviews and exceeded initial sales forecasts by 20%.\n\nChallenges:\n- Supply chain delays in Europe impacted delivery schedules.\n- Rising operational costs in North America reduced margins slightly.\n\nRecommendations:\n1. Expand distribution partnerships in Asia-Pacific to sustain growth.\n2. Address supply chain bottlenecks by diversifying suppliers.\n3. Continue investment in customer support training to m
# ...

# %%
# Initialize Gemini model (flash or pro)
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# Create a simple prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("user", "Summarize this report in 3 sentences.")
])

# Run the chain
chain = prompt | llm
response = chain.invoke({"input": "Quarterly Performance Review – Q4 2025..."})

print(response.content)
