# %%
import pandas as pd

maindf = pd.ExcelFile("dataset.xlsx" , engine='openpyxl')

# importing individual excel sheets
sku_master = pd.read_excel(maindf , sheet_name=maindf.sheet_names[0])
sales = pd.read_excel(maindf , sheet_name=maindf.sheet_names[1])
opening_stock = pd.read_excel(maindf , sheet_name=maindf.sheet_names[2])
stock_transfer = pd.read_excel(maindf , sheet_name=maindf.sheet_names[3])

maindf.sheet_names
# Out:
# ['SKU MASTER', 'Sales', 'Opening Stock', 'STOCK TRANSFER']

# %%
# Displaying the first few rows of each dataframe
display(sku_master.head())
display(sales.head())
display(opening_stock.head())
display(stock_transfer.head())
# Out:
#     SKU      Description  Category  Price
# 0  F001  Prateek England  Fashion    1128
# 1  F002    Lucy Phillepe  Fashion    1760
# 2  F003         Badlands  Fashion    1245
# 3  F004      Allen Dolly  Fashion    3389
# 4  F005           Bucchi  Fashion    9300
#         Date   SKU     Product Name    City  Sales
# 0 2025-01-01  F001  Prateek England  Mumbai     81
# 1 2025-01-01  F002    Lucy Phillepe  Mumbai      9
# 2 2025-01-01  F003         Badlands  Mumbai     45
# 3 2025-01-01  F004      Allen Dolly  Mumbai     32
# 4 2025-01-01  F005           Bucchi  Mumbai     17
#     SKU      Description  Category  MUMBAI  Pune  Aurangabad  Nashik
# 0  F001  Prateek England  Fashion       67   232          85      59
# 1  F002    Lucy Phillepe  Fashion       75   157          89      75
# 2  F003         Badlands  Fashion       78   170          92      71
# 3  F004      Allen Dolly  Fashion       72   184          87      74
# ...
